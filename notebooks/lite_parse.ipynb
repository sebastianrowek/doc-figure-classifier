# %%
from liteparse import LiteParse

# %% [markdown]
# ### Only Page Complexity

# %%
parser = LiteParse(ocr_enabled=False)
pages = parser.is_complex("../../../data/reports/datagroup_ann_rep_2022_2023.pdf")

# %%
for index, page in enumerate(pages):
    if page.layout.figure_count > 0:
        print(f"Page {index + 1}: {page.layout.figure_count}")
# Out:
# Page 2: 4
# Page 6: 1
# Page 8: 6
# Page 9: 5
# Page 10: 4
# Page 11: 1
# Page 12: 1
# Page 16: 1
# Page 17: 4
# Page 20: 1
# Page 21: 1
# Page 23: 1
# Page 24: 2
# Page 25: 1
# Page 26: 1
# Page 32: 2
# Page 34: 2
# Page 35: 1
# Page 36: 1
# Page 37: 1
# Page 38: 1
# Page 39: 1
# Page 40: 1
# Page 41: 1
# Page 43: 3
# Page 44: 2
# Page 48: 1
# Page 55: 1
# Page 56: 1
# Page 58: 2
# Page 61: 1
# Page 63: 1
# Page 64: 1
# Page 65: 1
# Page 66: 1
# Page 67: 1
# Page 68: 1
# Page 77: 2

# %% [markdown]
# ### Extract Page Layout
# The `extract_blocks` argument for the LiteParse class is a feature of the 2.13.0 release.<br>
# This realease is currently not available for my platform so we can't try it for now.

# %%
parser = LiteParse(
    ocr_enabled=True,              # Enable OCR (default: True)
    ocr_language="de",            # Tesseract language code
    max_pages=10,
    output_format="json",          # "json" | "text" | "markdown"
    image_mode="placeholder",      # Markdown image handling: "placeholder" | "off" | "embed"
    extract_images=True,           # Extract image bytes + metadata (default: False)
    image_output_dir="../../../data/reports/images",   # Write images and return name/path metadata (optional)
    extract_annotations=False,     # Include page annotations in structured output
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 parser = LiteParse(
#       2     ocr_enabled=True,              # Enable OCR (default: True)
#       3     ocr_language="de",            # Tesseract language code
#       4     max_pages=10,
#
# TypeError: LiteParse.__init__() got an unexpected keyword argument 'extract_blocks'

# %%
with open("../../../data/reports/datagroup_ann_rep_2022_2023.pdf", "rb") as f:
    result = parser.parse(f.read())

# %%
print(result.pages[2].complexity)
# Out:
# None

# %%
dir(result.pages[2])
# Out:
# ['__annotations__',
#  '__class__',
#  '__dataclass_fields__',
#  '__dataclass_params__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__match_args__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'annotations',
#  'complexity',
#  'content_bounds',
#  'form_fields',
#  'height',
#  'markdown',
#  'page_num',
#  'structure_tree',
#  'text',
#  'text_items',
#  'vector_graphics',
#  'width']

# %%
dir(result)
# Out:
# ['__annotations__',
#  '__class__',
#  '__dataclass_fields__',
#  '__dataclass_params__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__match_args__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'creator',
#  'doc_meta',
#  'form_type',
#  'get_page',
#  'image_error_count',
#  'images',
#  'num_pages',
#  'page_errors',
#  'pages',
#  'producer',
#  'screenshots',
#  'text',
#  'total_pages',
#  'xfa_packets']
